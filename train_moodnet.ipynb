# %%
import torch, copy, os, datetime, math
import pandas as pd
import torch.nn as nn
import numpy as np
from tqdm import tqdm
from torch.utils.data import DataLoader, random_split

VOCAB_SIZE = 128
MODELS_PATH = "models"
DS_PATH = "dataset/"
DATASET = "emociones.csv"

os.environ["CUDA_LAUNCH_BLOCKING"] = "1"

PYTORCH_DEVICE = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(PYTORCH_DEVICE)
torch.cuda.empty_cache()
torch.cuda.synchronize()
if not os.path.exists("./dataset"): os.mkdir("./dataset")
# Out:
# cuda:0

# %%
# Crea un tokenizador desde cero
from tokenizers import Tokenizer, models, trainers, pre_tokenizers

tokenizer = Tokenizer(models.WordPiece(unk_token="[PAD]"))
tokenizer.pre_tokenizer = pre_tokenizers.Whitespace()

trainer = trainers.WordPieceTrainer(vocab_size=VOCAB_SIZE, special_tokens=["[PAD]"])
tokenizer.train([f"{DS_PATH}{DATASET}"], trainer)

tokenizer.save("custom_tokenizer.json")

# %%
# Carga tokenizador
from transformers import PreTrainedTokenizerFast
tokenizer = PreTrainedTokenizerFast(tokenizer_file="custom_tokenizer.json")
tokenizer.pad_token = "[PAD]"

# %%
# Data gen
class DataGen:
    def __init__(self):
        self.t, self.l = [], []
    
    def append_items(self,t,l):
        self.t.append(t)
        self.l.append(l)

    def to_numpy(self):
        self.t = np.array(self.t)
        self.l = np.array(self.l)

    def __len__(self):
        return len(self.l)

    def __getitem__(self, idx):
        return self.t[idx],self.l[idx]
    
    def __str__(self):
        return f"{self.t[:3]}, {self.l[:3]}"

# %%
# Carga dataset
a = []
def parse_data():
    file = pd.read_csv(f"./dataset/{DATASET}")
    data = DataGen()
    for _, row in tqdm(file.iterrows(),total=1,desc="Cargando dataset"):
        a.append(row[0])
        text_tokenized = tokenizer(row["text"],padding="max_length",truncation=True,max_length=VOCAB_SIZE,)
        data.append_items(text_tokenized["input_ids"],row["label"])
    data.to_numpy()
    return data

train_gen = parse_data()

# %%
print(train_gen)
print(train_gen.__len__())

# %%
class Emotions(torch.nn.Module):
    def __init__(self) -> None:
        super().__init__()

    def save(self, project_name: str, path: str = './models'):
        model_id = str(project_name)
        save_dir = os.path.join(path, model_id)
        os.makedirs(save_dir, exist_ok=True)
        model_dir = os.path.join(save_dir, 'model.pt')
        model_scripted = torch.jit.script(self)
        model_scripted.save(model_dir)

    @staticmethod
    def load(model_id: str):
        model = torch.jit.load(os.path.join(MODELS_PATH, model_id, 'model.pt'))
        model.to(PYTORCH_DEVICE)
        return model

# %%
# Modelo Transformers
class EmotionsNet(Emotions):
    def __init__(self,num_classes=6,vocab_size=VOCAB_SIZE):
        super().__init__()

        self.embedding = nn.Embedding(vocab_size, 512)
        self.positional_encoding = nn.Parameter(torch.zeros(vocab_size, 512))
        self.transformer_encoder = nn.TransformerEncoder(
            nn.TransformerEncoderLayer(d_model=512, nhead=4, dim_feedforward=512, batch_first=True, dropout=0.1),
            num_layers=2
        )
        self.fc = nn.Sequential(
            nn.Linear(vocab_size*512, 512),
            nn.ReLU(),
            nn.Dropout(0.35),
            nn.Linear(512, 256),
            nn.ReLU(),
            nn.Dropout(0.35),
            nn.Linear(256, num_classes),
        )

    def forward(self, x):
        embedded = self.embedding(x) + self.positional_encoding
        encoded = self.transformer_encoder(embedded.transpose(0, 1))
        encoded = encoded.transpose(0, 1)
        flattened = encoded.flatten(1)
        output = self.fc(flattened)
        return output
    
    @staticmethod
    def load(model_id: str):
        return Emotions.load(model_id)

# %%
# Modelo Transformers 2

class EmotionsNet(nn.Module):
    def __init__(self, num_classes=6, vocab_size=VOCAB_SIZE, max_seq_len=128, d_model=512, nhead=4, num_layers=4, dim_feedforward=512, dropout=0.1):
        super().__init__()
        self.d_model = d_model
        self.embedding = nn.Embedding(vocab_size, d_model)

        pe = torch.zeros(max_seq_len, d_model)
        position = torch.arange(0, max_seq_len, dtype=torch.float).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() * (-math.log(10000.0) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        self.register_buffer("positional_encoding", pe.unsqueeze(0))

        self.layer_norm = nn.LayerNorm(d_model)
        encoder_layer = nn.TransformerEncoderLayer(
            d_model=d_model, nhead=nhead,
            dim_feedforward=dim_feedforward,
            dropout=dropout,
            batch_first=True
        )
        self.transformer = nn.TransformerEncoder(encoder_layer, num_layers=num_layers)

        self.classifier = nn.Sequential(
            nn.Linear(d_model, 256),
            nn.ReLU(inplace=True),
            nn.Dropout(0.2),
            nn.Linear(256, num_classes)
        )

    def forward(self, x):
        """
        x: LongTensor [batch, seq_len] (seq_len ≤ max_seq_len)
        """
        emb = self.embedding(x) * math.sqrt(self.d_model)
        pe = self.positional_encoding[:, :x.size(1), :]
        h = self.layer_norm(emb + pe)
        h = self.transformer(h)
        h = h.mean(dim=1)
        out = self.classifier(h)
        return out
    
    @staticmethod
    def load(model_id: str):
        return torch.jit.load(model_id)
    
    def save(self, project_name: str, path: str = './models'):
        model_id = str(project_name)
        save_dir = os.path.join(path, model_id)
        os.makedirs(save_dir, exist_ok=True)
        model_dir = os.path.join(save_dir, 'model.pt')
        model_scripted = torch.jit.script(self)
        model_scripted.save(model_dir)

# %%
# Cantidad de parametros
model = EmotionsNet().to(PYTORCH_DEVICE)
sum(p.numel() for p in model.parameters())

# %%
def train_emotions_net(checkpoint_model_id=None, batch_size=64, vocab_size=100, train_loader=None, test_loader=None,
                    epochs=100, learning_rate=0.0001, project_name=str(datetime.time()), cant_emotions=6):
    # Division del dataset
    if not test_loader:
        train_size = int(0.8 * len(train_gen))  # 80% para entrenamiento
        test_size = len(train_gen) - train_size  # 20% para prueba
        train_dataset, test_dataset = random_split(train_gen, [train_size, test_size])
        train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
        test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

    model = None
    if checkpoint_model_id:
        model = EmotionsNet(num_classes=cant_emotions,vocab_size=vocab_size).load(model_id=checkpoint_model_id).type(torch.FloatTensor).to(PYTORCH_DEVICE)
    else:
        model = EmotionsNet(num_classes=cant_emotions,vocab_size=vocab_size).to(PYTORCH_DEVICE)

    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)
    best_state = copy.deepcopy(model.state_dict())
    best_loss = float("inf")
    patience = 30
    patience_count = 0

    try:
        with open(f"./models/emotions2{str(datetime.datetime.now())}.txt","w") as file:
            for epoch in range(1,epochs+1):
                loading_bar = tqdm(total=len(train_loader))
                total_accu, total_count = 0, 0
                running_loss = 0

                for _, data in enumerate(train_loader):
                    text, label = data
                    text: torch.Tensor = text.type(torch.LongTensor).to(PYTORCH_DEVICE)
                    expected_label: torch.Tensor = label.type(torch.LongTensor).to(PYTORCH_DEVICE)

                    optimizer.zero_grad()
                    op = model(text)
                    output_label:torch.Tensor = op

                    loss = criterion(output_label, expected_label)
                    loss.backward()
                    optimizer.step()

                    total_accu += (output_label.argmax(1) == expected_label).sum().item()
                    total_count += expected_label.size(0)
                    running_loss += loss.item() * text.size(0)
                    loading_bar.set_description_str(f'Training {project_name} | lr: {learning_rate} | Epoch {epoch}/{epochs-1} | Loss {(running_loss / len(train_loader.dataset)):.8f} |  Acc {((total_accu / total_count) * 100):.4f}')
                    loading_bar.update()
                loading_bar.set_description_str(f'Training {project_name} | lr: {learning_rate} | Epoch {epoch}/{epochs-1} | Loss {(running_loss / len(train_loader.dataset)):.8f} |  Acc {((total_accu / total_count) * 100):.4f}')
                loading_bar.close()
                epoch_loss = running_loss / len(train_loader.dataset)
                file.write(f"\nTrain -> Loss lbl: {epoch_loss} || Train Acc lbl: {((total_accu / total_count) * 100):.4f}")
                
                if epoch_loss < best_loss:
                    best_loss = epoch_loss
                    best_state = copy.deepcopy(model.state_dict())
                    patience_count = 0
                else:
                    patience_count += 1

                if patience_count == patience:
                    break
                
                if epoch%10 == 0: model.save(f"{project_name}{epoch}")

                model.eval()
                test_correct = 0
                test_total = 0
                test_running_loss = 0.0
                with torch.no_grad():
                    for data in test_loader:
                        text, label = data
                        text: torch.Tensor = text.type(torch.LongTensor).to(PYTORCH_DEVICE)
                        expected_label: torch.Tensor = label.type(torch.LongTensor).to(PYTORCH_DEVICE)

                        op = model(text)
                        output_label:torch.Tensor = op

                        test_total += expected_label.size(0)
                        test_correct += (output_label.argmax(1) == expected_label).sum().item()

                        test_loss = criterion(output_label, expected_label)
                        test_running_loss += test_loss.item() * text.size(0)
                test_epoch_loss = test_running_loss / len(test_loader.dataset)
                model.train()
                print(f"Test Loss: {test_epoch_loss} || Test Acc: {(test_correct / test_total) * 100}\n")
                file.write(f"\nTest -> Loss lbl: {test_epoch_loss} || Test Acc lbl: {((test_correct / test_total) * 100):.4f}")
        file.close() 
    except Exception as e:
        print("ERROR: ",e)
        model.save(project_name+"Crashed", weights=best_state)
        return
    finally:
        loading_bar.close()

    model.save(project_name, weights=best_state)

# %%
BS = 512
train_size = int(0.8 * len(train_gen))  # 80% para entrenamiento
test_size = len(train_gen) - train_size  # 20% para prueba
train_dataset, test_dataset = random_split(train_gen, [train_size, test_size])
train_loader = DataLoader(train_dataset, batch_size=BS, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=BS, shuffle=False)

# %%
# Entrenar
NOMBRE = "emotions_2"
LR = 0.0001
EPOCAS = 60
NUM_EMOTIONS = 6

if os.path.exists(f"{MODELS_PATH}/{NOMBRE}"):train_emotions_net(project_name=NOMBRE+"NEW",checkpoint_model_id=NOMBRE, train_loader=train_loader, test_loader=test_loader,
                                                        epochs=EPOCAS,learning_rate=LR, batch_size=BS, vocab_size=VOCAB_SIZE, cant_emotions=NUM_EMOTIONS)
else:train_emotions_net(project_name=NOMBRE,checkpoint_model_id=None,epochs=EPOCAS,learning_rate=LR, batch_size=BS, vocab_size=VOCAB_SIZE, cant_emotions=NUM_EMOTIONS, train_loader=train_loader, test_loader=test_loader,)

# %%
# Load model for inference
def get_model(model_id):
    model = torch.jit.load(os.path.join(MODELS_PATH, model_id, 'model.pt'))
    model.to(PYTORCH_DEVICE)
    model.eval()
    return model

modelo = get_model("emotions_2")

# %%
modelo = EmotionsNet()
modelo.load_state_dict(torch.load(os.path.join(MODELS_PATH, "emotions_2", 'weights.pt'),weights_only=True))
modelo = modelo.to("cpu")
modelo.eval()
torch.save(modelo,"emotions_cpu.pt")

# %%
# Inference
test_texto = "Estoy impresionado por verte"
text_tokenized = tokenizer(test_texto,padding="max_length",truncation=True,max_length=VOCAB_SIZE,)

text_tokenized = torch.tensor(text_tokenized["input_ids"]).type(torch.LongTensor).to(PYTORCH_DEVICE).unsqueeze(0)
print(text_tokenized.shape)
answ = modelo(text_tokenized)
print(answ)
# 0-sadness  1-joy  2-love  3-anger  4-fear  5-surprise
answ = list(answ[0])
print("Emocion: ", answ.index(max(answ)))
# Out:
# torch.Size([1, 128])
# tensor([[-4.5979, -0.6861, -2.7587, -6.5248, -1.3328,  7.8469]],
#        device='cuda:0', grad_fn=<DifferentiableGraphBackward>)
# Emocion:  5

# %%
# Export to ONNX
dummy_input = torch.randint(1,VOCAB_SIZE,(1,VOCAB_SIZE)).to(PYTORCH_DEVICE)
torch.onnx.export(modelo, dummy_input, f"{MODELS_PATH}/emotions.onnx", export_params=True,
                  opset_version=11, do_constant_folding=True, input_names=["input"], output_names=["output"],
                  dynamic_axes={"input": {0:"batch_size"}, "output": {0:"batch_size"}})

import onnx
model_path = f"{MODELS_PATH}/emotions.onnx"
onnx_model = onnx.load(model_path)
onnx.checker.check_model(onnx_model)
print("Conversion was successful")

# %%
import onnxruntime as ort
model_path = f"{MODELS_PATH}/emotions.onnx"
session = ort.InferenceSession(model_path)

test_texto = "Que bonito dia"

text_tokenized = tokenizer(test_texto,padding="max_length",truncation=True,max_length=VOCAB_SIZE,)
text_tokenized = torch.tensor(text_tokenized["input_ids"]).type(torch.LongTensor).unsqueeze(0)

numpy_input = text_tokenized.numpy()

input_name = session.get_inputs()[0].name
output_name = session.get_outputs()[0].name

result = session.run([output_name], {input_name: numpy_input})
output = result[0]
print("Resultado de la inferencia:", output)

# %%
# Mimir
SLEEP = True
if SLEEP:
    try:
        os.system('shutdown /s /t 0')
    except:
        os.system("rundll32.exe powrprof.dll,SetSuspendState 0,1,0")
